# %% [markdown]
# ## Referências:
# - Abandono escolar na pandemia: https://inesc.org.br/abandono-no-ensino-medio-brasileiro-duplicou-na-pandemia/
# - Dados covid: https://infoms.saude.gov.br/extensions/covid-19_html/covid-19_html.html

# %%
import pandas as pd

a_uf = pd.read_excel('bases/abandono_por_uf.xlsx')
a_uf.head()
# Out:
#   Número de estudantes que abandonaram o EM   2019  2020   2021
# 0                                      Acre   2272  1249   2407
# 1                                   Alagoas   6747   527   8923
# 2                                     Amapá   3068   720   2509
# 3                                  Amazonas  20375   335  11215
# 4                                     Bahia  37659  3922  65374

# %%
a_regiao = pd.read_excel('bases/abandono_por_regiao.xlsx')
a_regiao.head()
# Out:
#      Região    2019    2020    2021  Var. em 2019 e 2020  Var. em 2020 e 2021
# 0    Brasil  341211  165644  377526               -0.510                 1.28
# 1     Norte   68373    8735   82653               -0.870                 8.46
# 2  Nordeste  105496   42739  135909               -0.590                 2.18
# 3   Sudeste   97893   65287   89809               -0.330                 0.38
# 4       Sul   42228   42312   55492                0.002                 0.31

# %%
c_regiao = pd.read_excel('bases/covid_por_regiao.xlsx')
c_regiao.head()
# Out:
#          Região  População  Casos novos notificados na semana epidemiológica  \
# 0       Sudeste   88371433                                             57068
# 1           Sul   29975984                                             40584
# 2      Nordeste   57071654                                             22090
# 3  Centro-Oeste   16297074                                             30329
# 4         Norte   18430980                                              7034
#
#    Casos Acumulados  Incidência covid-19 (100 mil hab)  \
# 0          15253488                       17260.654809
# 1           8125900                       27108.034218
# 2           7482295                       13110.352470
# 3           4422046                       27133.987365
# 4           2927135                       15881.602606
#
#    Óbitos novos notificados na semana epidemiológica  Óbitos Acumulados  \
# 0                                                465             341269
# ...

# %%
c_uf = pd.read_excel('bases/covid_por_uf.xlsx')
c_uf.head()
# Out:
#    UF  População  Casos novos notificados na semana epidemiológica  \
# 0  AC     881935                                               958
# 1  AL    3337357                                               676
# 2  AM    4144597                                               143
# 3  AP     845731                                               456
# 4  BA   14873064                                              6180
#
#    Casos Acumulados  Incidência covid-19 (100 mil hab)  \
# 0            166045                       18827.351222
# 1            343586                       10295.152721
# 2            638685                       15410.062788
# 3            186825                       22090.357336
# 4           1823743                       12262.053065
#
#    Óbitos novos notificados na semana epidemiológica  Óbitos Acumulados  \
# 0                                                  1               2067
# 1                                                 17               7317
# ...
